# %% [markdown]
# - This notebook is used for performing preprocessing of GTEx expression data
# - webiste available at https://www.gtexportal.org/home/datasets
# - We're analyzing RNA Sequencing Gene read counts

# %%
import pandas as pd
import numpy as np

# %%
# unzip within read_csv would be a more optimal approach
raw = pd.read_csv("~/dataSets/GTEX/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_reads.gct",sep = "\t",skiprows = 2)

# %%
raw = pd.read_csv("~/dataSets/GTEX/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_reads.gct",sep = "\t",skiprows = 2,nrows = 5)

# %%
raw
# Out:
#                 Name  Description  GTEX-1117F-0226-SM-5GZZ7  \
# 0  ENSG00000223972.5      DDX11L1                         0
# 1  ENSG00000227232.5       WASH7P                       187
# 2  ENSG00000278267.1    MIR6859-1                         0
# 3  ENSG00000243485.5  MIR1302-2HG                         1
# 4  ENSG00000237613.2      FAM138A                         0
#
#    GTEX-1117F-0426-SM-5EGHI  GTEX-1117F-0526-SM-5EGHJ  \
# 0                         0                         0
# 1                       109                       143
# 2                         0                         1
# 3                         0                         0
# 4                         0                         0
#
#    GTEX-1117F-0626-SM-5N9CS  GTEX-1117F-0726-SM-5GIEN  \
# 0                         0                         0
# 1                       251                       113
# 2                         0                         0
# 3                         1                         0
# 4                         0                         0
#
#    GTEX-1117F-1326-SM-5EGHH  GTEX-1117F-2426-SM-5EGGH  \
# 0                         0                         0
# 1                       139                       199
# 2                         0                         0
# 3                         0                         0
# 4                         0                         0
#
#    GTEX-1117F-2526-SM-5GZY6  ...  GTEX-ZZPU-1126-SM-5N9CW  \
# 0                         0  ...                        0
# 1                       473  ...                       72
# 2                         0  ...                        0
# 3                         0  ...                        0
# 4                         1  ...                        1
#
#    GTEX-ZZPU-1226-SM-5N9CK  GTEX-ZZPU-1326-SM-5GZWS  GTEX-ZZPU-1426-SM-5GZZ6  \
# 0                        2                        0                        0
# 1                       96                      136                       79
# 2                        0                        0                        0
# 3                        0                        1                        0
# 4                        0                        0                        0
#
#    GTEX-ZZPU-1826-SM-5E43L  GTEX-ZZPU-2126-SM-5EGIU  GTEX-ZZPU-2226-SM-5EGIV  \
# 0                        0                        0                        0
# 1                       89                       86                       49
# 2                        0                        0                        0
# 3                        2                        2                        0
# 4                        0                        0                        0
#
#    GTEX-ZZPU-2426-SM-5E44I  GTEX-ZZPU-2626-SM-5E45Y  GTEX-ZZPU-2726-SM-5NQ8O
# 0                        0                        1                        1
# 1                       84                       34                       66
# 2                        0                        0                        0
# 3                        1                        0                        0
# 4                        0                        0                        0
#
# [5 rows x 17384 columns]

# %% [markdown]
# # 7 gb of raw GTEX genes

# %% [markdown]
# # Trim Genes by using protein coding gene list from biomart

# %%
# load in list for protein coding genes
proteinGenes = list(pd.read_csv("/home/ydong/dataSets/proteinCodedGenes.csv",header = None)[0])

# %%
# get the protein coding GTEx genes, and trim ENSGXXXX.Y to ENSGXXXX
rawNames = list(raw["Name"])
names = []
keepL = []
for i in range(len(rawNames)):
    curr = rawNames[i].split(".")[0]
    if curr in proteinGenes:
        keepL.append(i)
        names.append(curr)
raw = raw.iloc[keepL,:]

# %%
raw = raw.set_index("Name")
originNames = list(raw.index)

# %%
# get rid of dulplicate genes
dup = list(set([x for x in names if names.count(x) > 1]))

# check for each duplication
for j in range(len(dup)):

    allZero = True
    # get their column number in normedMat
    indices = [i for i, x in enumerate(names) if x == dup[j]]
    
    curr = raw.iloc[indices,:].drop(["Description"],axis = 1)
       
    # pick the gene with highest median expression across individuals:
    meds = []
    for c in range(len(curr.index)):
        currMed = np.median(curr.iloc[c,:])
        meds.append(currMed)
        if currMed != 0:
            allZero = False
        
    # if all of the medians are zero, discard all of the currently chosen genes 
    if allZero == True:
        for d in list(curr.columns):
            originNames.remove(d)
    # keep the one with highest "expression" and discard the rest
    else:
        bestI = meds.index(max(meds))
        choices = list(curr.index)
        choices.pop(bestI)
        for d in range(len(choices)):
            originNames.remove(choices[d])

# %%
len(originNames)
# Out:
# 19199

# %% [markdown]
# # removed 18 duplications

# %%
raw = raw.loc[originNames,:]
raw = raw.drop("Description",axis = 1)

# %% [markdown]
# # Removed 5 tissues, 50 left

# %%
# tissue annotation
samples = pd.read_csv('/home/ydong/dataSets/GTEX/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt', sep="\t")
#find the sample IDs for muscle samples
#all of them are Muscle-skeletal samples
tissues = samples[["SAMPID","SMTSD"]]
tissues = tissues.set_index("SAMPID")
tissueTypes = list(tissues["SMTSD"].unique())

# %%
# remove tissues with < 50 samples
count = 0
dropList = []
for i in tissueTypes:
    if sum(tissues["SMTSD"] == i) <=50:
        dropList.append(i)
    count +=1
for i in dropList:
    tissueTypes.remove(i)

# %%
rawTis = list(raw.columns)
dropList = []
for i in rawTis:
    if tissues["SMTSD"][i] not in tissueTypes:
        dropList.append(i)
        
raw = raw.drop(dropList,axis = 1)

# %% [markdown]
# # Library Normalization (like DESEQ2)

# %%
# get median expression
medianExpression = []
for n in raw.index:
    cols = raw.loc[n,:]
    medianExpression.append(int(np.median(list(cols))))
medianExpression = np.array(medianExpression)

# %%
# compute fold change regardless of nan values
FC = []
for sample in list(raw.columns):
    currFC = []
    currCol = np.array(raw[sample])
    currFC = currCol/medianExpression
    FC.append(np.nanmedian(currFC))
# Out:
# /home/bkotis/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /home/bkotis/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %%
for i in range(len(FC)):
# for i in [0,1]:
    currSample = list(raw.columns)[i]
    currCol = raw[currSample]
    currFC = FC[i]
    raw.iloc[:,i] = np.around(currCol / currFC, 3)

# %%
raw.to_csv("normedGTEx.csv")

# %% [markdown]
# # Keep genes with median expression > 0 in at least 1 tissue

# %%
len(tissueTypes)
# Out:
# 50

# %%
# list of gtex corresponding tissues
indexDict = {key: [] for key in tissueTypes} 
gtexTis = []
dropList = []
for i in range(len(raw.columns)):
    currSamp  = raw.columns[i]
    currTis = tissues["SMTSD"][currSamp]
    if currTis not in indexDict:
        dropList.append(currSamp)
    else:
        gtexTis.append(currTis)
        indexDict[currTis].append(i)

# %%
#Loop through all tissues to see if there's one tissue with median > 0
dropGeneList = []
for currGene in raw.index:
    currRow = raw.loc[currGene,:]
    keep = False
    
    for currTis in tissueTypes:
        tisIdx = indexDict[currTis]
        currMedian = np.median(currRow.iloc[tisIdx])
        if currMedian >0:
            keep = True
            break
    
    if keep == False:
        dropGeneList.append(currGene)
# Out:
# /home/bkotis/miniconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/bkotis/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
len(dropGeneList)
# Out:
# 350

# %%
raw = raw.drop(dropGeneList,axis = 0)

# %%
raw.to_csv("GTExTrimmedNormedCounts.csv")

# %% [markdown]
# # generate median scale

# %%
# get median expression
medianExpression = []
for n in raw.index:
    cols = raw.loc[n,:]
    medianExpression.append(int(np.median(list(cols))))
medianExpression = np.array(medianExpression)

# %%
medianScale = pd.DataFrame(medianExpression,index = raw.index)
medianScale = medianScale[medianScale["0"]!= 0]
medianScale.to_csv("medianScale.csv")

# %%
medianScale
# Out:
#                          0
# Name
# ENSG00000186092.4        1
# ENSG00000187634.11     181
# ENSG00000188976.10    3276
# ENSG00000187961.13     759
# ENSG00000187583.10      47
# ...                    ...
# ENSG00000212907.2    86431
# ENSG00000198886.2   926360
# ENSG00000198786.2   223490
# ENSG00000198695.2    70595
# ENSG00000198727.2   513507
#
# [17088 rows x 1 columns]

# %% [markdown]
# ##  Log transform the matrix

# %%
raw = pd.read_csv("GTExTrimmedNormedCounts.csv",index_col = "Name")

# %%
raw = raw + 1
raw
# Out:
#                     GTEX-1117F-0226-SM-5GZZ7  GTEX-1117F-0426-SM-5EGHI  \
# Name
# ENSG00000186092.4                        1.0                     5.409
# ENSG00000187634.11                      21.0                    78.154
# ENSG00000188976.10                    3840.0                 11545.376
# ENSG00000187961.13                     509.0                   153.103
# ENSG00000187583.10                      86.0                    51.701
# ...                                      ...                       ...
# ENSG00000212907.2                    24132.0                193023.768
# ENSG00000198886.2                   273189.0               2186512.951
# ENSG00000198786.2                    85259.0                882866.942
# ENSG00000198695.2                    32049.0                362834.337
# ENSG00000198727.2                   127195.0               1406860.832
#
#                     GTEX-1117F-0526-SM-5EGHJ  GTEX-1117F-0626-SM-5N9CS  \
# Name
# ENSG00000186092.4                      2.332                     1.000
# ENSG00000187634.11                    19.645                   667.201
# ENSG00000188976.10                  4875.233                  2849.455
# ENSG00000187961.13                   380.551                   937.055
# ENSG00000187583.10                    80.905                    64.715
# ...                                      ...                       ...
# ENSG00000212907.2                  33625.216                 23698.461
# ENSG00000198886.2                 369734.195                263081.144
# ENSG00000198786.2                 158080.626                 35859.679
# ENSG00000198695.2                  68927.446                  6868.213
# ENSG00000198727.2                 188256.921                160673.555
#
#                     GTEX-1117F-0726-SM-5GIEN  GTEX-1117F-1326-SM-5EGHH  \
# Name
# ENSG00000186092.4                      2.549                     2.450
# ENSG00000187634.11                  1571.843                   167.705
# ENSG00000188976.10                  2784.830                  2497.233
# ENSG00000187961.13                   755.438                   721.457
# ENSG00000187583.10                   101.695                    92.326
# ...                                      ...                       ...
# ENSG00000212907.2                 278593.172                106976.597
# ENSG00000198886.2                3790888.580               1235995.620
# ENSG00000198786.2                 562079.123                131535.930
# ENSG00000198695.2                 147593.582                 27453.760
# ENSG00000198727.2                1326915.214                583906.326
#
#                     GTEX-1117F-2426-SM-5EGGH  GTEX-1117F-2526-SM-5GZY6  \
# Name
# ENSG00000186092.4                      3.239                     1.000
# ENSG00000187634.11                  1216.930                   134.066
# ENSG00000188976.10                  3156.147                  4508.605
# ENSG00000187961.13                   806.022                  1371.928
# ENSG00000187583.10                    44.666                  6259.471
# ...                                      ...                       ...
# ENSG00000212907.2                  18420.206                 21785.277
# ENSG00000198886.2                 217413.914                277694.504
# ENSG00000198786.2                  33406.594                 61912.503
# ENSG00000198695.2                   7649.264                 13150.880
# ENSG00000198727.2                 153199.172                148267.850
#
#                     GTEX-1117F-2826-SM-5GZXL  GTEX-1117F-2926-SM-5GZYI  ...  \
# Name                                                                    ...
# ENSG00000186092.4                      1.000                     2.185  ...
# ENSG00000187634.11                    50.583                    47.226  ...
# ENSG00000188976.10                  3615.565                  4657.954  ...
# ENSG00000187961.13                  1157.264                  1777.730  ...
# ENSG00000187583.10                   163.631                  3808.110  ...
# ...                                      ...                       ...  ...
# ENSG00000212907.2                  84269.452                 33848.959  ...
# ENSG00000198886.2                1004167.823                515795.675  ...
# ENSG00000198786.2                 109954.184                109019.234  ...
# ENSG00000198695.2                  19271.739                 44710.838  ...
# ENSG00000198727.2                 476347.122                228322.117  ...
#
#                     GTEX-ZZPU-1126-SM-5N9CW  GTEX-ZZPU-1226-SM-5N9CK  \
# Name
# ENSG00000186092.4                     5.019                    4.020
# ENSG00000187634.11                  781.744                  397.324
# ENSG00000188976.10                 3116.943                 2701.284
# ENSG00000187961.13                  631.021                  576.990
# ENSG00000187583.10                   34.159                   51.578
# ...                                     ...                      ...
# ENSG00000212907.2                243205.298               137282.941
# ENSG00000198886.2               1744130.055              1475150.392
# ENSG00000198786.2               1262615.931               276934.520
# ENSG00000198695.2                466105.225                97165.186
# ENSG00000198727.2               1415946.234               804644.206
#
#                     GTEX-ZZPU-1326-SM-5GZWS  GTEX-ZZPU-1426-SM-5GZZ6  \
# Name
# ENSG00000186092.4                       2.0                    4.442
# ENSG00000187634.11                     83.0                  181.154
# ENSG00000188976.10                   3026.0                 3208.193
# ENSG00000187961.13                   1134.0                  855.869
# ENSG00000187583.10                     29.0                   73.291
# ...                                     ...                      ...
# ENSG00000212907.2                  116738.0               179743.812
# ENSG00000198886.2                 1202014.0              1913739.507
# ENSG00000198786.2                  374008.0               666223.962
# ENSG00000198695.2                  140564.0               267236.503
# ENSG00000198727.2                  728290.0              1147631.123
#
#                     GTEX-ZZPU-1826-SM-5E43L  GTEX-ZZPU-2126-SM-5EGIU  \
# Name
# ENSG00000186092.4                     3.664                    2.091
# ENSG00000187634.11                   87.138                   50.091
# ENSG00000188976.10                 3331.957                 2577.727
# ENSG00000187961.13                  635.933                  114.455
# ENSG00000187583.10                   27.641                   23.909
# ...                                     ...                      ...
# ENSG00000212907.2                155728.358                78865.000
# ENSG00000198886.2               1465082.274               762931.545
# ENSG00000198786.2                616904.761               138239.909
# ENSG00000198695.2                238035.237                39553.000
# ENSG00000198727.2                881988.928               413092.273
#
#                     GTEX-ZZPU-2226-SM-5EGIV  GTEX-ZZPU-2426-SM-5E44I  \
# Name
# ENSG00000186092.4                     4.135                    1.000
# ENSG00000187634.11                   48.026                  489.701
# ENSG00000188976.10                 5642.504                 3445.031
# ENSG00000187961.13                  745.572                  499.756
# ENSG00000187583.10                 5766.338                   35.189
# ...                                     ...                      ...
# ENSG00000212907.2                 93407.945                44003.152
# ENSG00000198886.2                953131.497               506749.248
# ENSG00000198786.2                156583.701               367522.895
# ENSG00000198695.2                 38638.799               189908.412
# ENSG00000198727.2                577525.505               487819.645
#
#                     GTEX-ZZPU-2626-SM-5E45Y  GTEX-ZZPU-2726-SM-5NQ8O
# Name
# ENSG00000186092.4                     7.729                    1.000
# ENSG00000187634.11                  180.988                   13.647
# ENSG00000188976.10                 9809.511                 2309.589
# ENSG00000187961.13                  403.030                  516.614
# ENSG00000187583.10                   44.735                   24.349
# ...                                     ...                      ...
# ENSG00000212907.2                302434.861               101507.918
# ENSG00000198886.2               2722876.337               913490.294
# ENSG00000198786.2               1335442.161               337774.002
# ENSG00000198695.2                511059.589               114822.437
# ENSG00000198727.2               2071793.723               706177.404
#
# [18849 rows x 17329 columns]

# %%
new = np.log(raw)
new.to_csv("logTrimmedNormedCounts.csv")
